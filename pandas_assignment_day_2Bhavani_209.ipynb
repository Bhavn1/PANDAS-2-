# %%
import pandas as pd
import numpy as np
data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %% [markdown]
# ##### Write a Pandas program to create a dataframe by given dictionary and index as lables

# %% [markdown]
# ##### 1. Write a Pandas program to select the rows where the score is missing, i.e. is NaN

# %%
### code here
import pandas as pd
import numpy as np
data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df=pd.DataFrame(data,index=labels)
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# ##### 2. Write a Pandas program to change the score in row 'd' to 11.5.

# %%
### code here
df[df['score'].isnull()]
# Out:
#     name  score  attempts qualify
# d  James    NaN         3      no
# h  Laura    NaN         1      no

# %% [markdown]
# ##### 3. Write a Pandas program to select the 'name' and 'score' columns from the following DataFrame.

# %%
#### code here
df.loc['d','score']=11.5
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# ##### 4.  Write a Pandas program to calculate the mean score for each different student in DataFrame.

# %%
###  code here
df.score.mean()
# Out:
# 13.333333333333334

# %% [markdown]
# ##### 5. Write a Pandas program to append a new row 'k' to data frame with any value for each column. Now delete the row 'c' and return the original DataFrame.

# %%
### code here
df.loc['k']=(['sai',30.0,3,'yes'])
print(df)
print()
df1=df.drop('c')
print(df1)
print()
print(df.drop('k'))
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# k        sai   30.0         3     yes
#
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# k        sai   30.0         3     yes
#
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James   11.5         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# ###### import the titanic dataset

# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r"titanic.csv")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True  NaN  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False  NaN  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True  NaN  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False  NaN  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
# [891 rows x 16 columns]

# %% [markdown]
# ##### 1. Write a Pandas program to create a Pivot table and find the total fare amount class wise, gender wise.

# %%
#### code here
pd.pivot_table(df,index=['class','sex'],values=['fare'])
# Out:
#                      fare
# class  sex
# First  female  106.125798
#        male     67.226127
# Second female   21.970121
#        male     19.741782
# Third  female   16.118810
#        male     12.661633

# %% [markdown]
# ##### 2. Write a Pandas program to create a Pivot table and find survival rate by gender.

# %%
### code here
pivoted=df.pivot_table(columns='sex',index='survived')
pivoted
# Out:
#          adult_male                  age                alone            \
# sex          female      male     female       male    female      male
# survived
# 0               0.0  0.959402  25.046875  31.618056  0.333333  0.741453
# 1               0.0  0.807339  28.847716  27.276022  0.424893  0.587156
#
#                fare                parch              pclass            \
# sex          female       male    female      male    female      male
# survived
# 0         23.024385  21.960993  1.037037  0.207265  2.851852  2.476496
# 1         51.938573  40.821484  0.515021  0.357798  1.918455  2.018349
#
#              sibsp
# sex         female      male
# survived
# 0         1.209877  0.440171
# 1         0.515021  0.385321

# %% [markdown]
# ###### 3. Write a Pandas to create to find the total count no of people survived pclass wise, class wise and gender wise.

# %%
### code here
pd.crosstab([df['pclass'],df['class']],columns=df['sex'])
# Out:
# sex            female  male
# pclass class
# 1      First       94   122
# 2      Second      76   108
# 3      Third      144   347

# %% [markdown]
# ###### 4. Write a Pandas program to create a Pivot table and calculate how many women and men were in a particular cabin class.

# %%
###  code here
df.pivot_table(index=['sex'], columns=['pclass'], aggfunc='count')
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 12         0       3    male  20.0      0      0   8.0500        S   Third
# 13         0       3    male  39.0      1      5  31.2750        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 17         1       2    male   NaN      0      0  13.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
# 19         1       3  female   NaN      0      0   7.2250        C   Third
#
#       who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0     man        True  NaN  Southampton    no  False          NaN
# 1   woman       False    C    Cherbourg   yes  False          NaN
# 2   woman       False  NaN  Southampton   yes   True          NaN
# 3   woman       False    C  Southampton   yes  False          NaN
# 4     man        True  NaN  Southampton    no   True          NaN
# 5     man        True  NaN   Queenstown    no   True          NaN
# 6     man        True    E  Southampton    no   True          NaN
# 7   child       False  NaN  Southampton    no  False          NaN
# 8   woman       False  NaN  Southampton   yes  False          NaN
# 9   child       False  NaN    Cherbourg   yes  False          NaN
# 10  child       False    G  Southampton   yes  False          NaN
# 11  woman       False    C  Southampton   yes   True          NaN
# 12    man        True  NaN  Southampton    no   True          NaN
# 13    man        True  NaN  Southampton    no  False          NaN
# 14  child       False  NaN  Southampton    no   True          NaN
# 15  woman       False  NaN  Southampton   yes   True          NaN
# 16  child       False  NaN   Queenstown    no  False          NaN
# 17    man        True  NaN  Southampton   yes   True          NaN
# 18  woman       False  NaN  Southampton    no  False          NaN
# 19  woman       False  NaN    Cherbourg   yes   True          NaN

# %% [markdown]
# ##### 5. Write a Pandas program to count the number of missing values in each column.

# %%
#### code here
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# Unnamed: 15    891
# dtype: int64

# %% [markdown]
# ##### 6. Write a Pandas program to replace null values with the value from the previous row or the next row in a given DataFrame.

# %%
### code here
df.fillna(1.3)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   1.3      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True  1.3  Southampton    no  False          1.3
# 1    woman       False    C    Cherbourg   yes  False          1.3
# 2    woman       False  1.3  Southampton   yes   True          1.3
# 3    woman       False    C  Southampton   yes  False          1.3
# 4      man        True  1.3  Southampton    no   True          1.3
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  1.3  Southampton    no   True          1.3
# 887  woman       False    B  Southampton   yes   True          1.3
# 888  woman       False  1.3  Southampton    no  False          1.3
# 889    man        True    C    Cherbourg   yes   True          1.3
# 890    man        True  1.3   Queenstown    no   True          1.3
#
# [891 rows x 16 columns]

# %% [markdown]
# ###### 7. Write a Pandas program to replace nulls, with median or mean of the specified columns in a given DataFrame.

# %%
### code here
df['age'].fillna(df['age'].median(), inplace=True)
print(df)
df['fare'].fillna(int(df['fare'].mean()), inplace=True)
print(df)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True  NaN  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False  NaN  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True  NaN  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False  NaN  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
# [891 rows x 16 columns]
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True  NaN  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False  NaN  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True  NaN  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False  NaN  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
# [891 rows x 16 columns]

# %% [markdown]
# ###### 8. Write a Pandas program to select first 2 rows, 2 columns and specific two columns from the dataframe.

# %%
#### code here
print(df.iloc[:2])
print(df.iloc[:,:2].head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0    man        True  NaN  Southampton    no  False          NaN
# 1  woman       False    C    Cherbourg   yes  False          NaN
#    survived  pclass
# 0         0       3
# 1         1       1
# 2         1       3
# 3         1       1
# 4         0       3

# %% [markdown]
# ###### 9. Write a Pandas program to remove the duplicates from 'embark_town' column of titanic dataset.

# %%
#### code here
df.dropna(subset='embark_town',inplace=True)
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      0
# alive            0
# alone            0
# Unnamed: 15    889
# dtype: int64

# %% [markdown]
# ###### 10. Write a Pandas program to find out the survived is 1 details by the 'Southampton' in who is the 'child' from dataset.

# %%
### code here
m=pd.crosstab(df['survived'],df['embark_town'][10])
m
# Out:
# col_0     Southampton
# survived
# 0                 549
# 1                 340

# %% [markdown]
# ###### 11. Write a Pandas program to filter all records starting from the 2nd row, access every 5th row from the dataframe.

# %%
### code here
df.iloc[1::5].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 11         1       1  female  58.0      0      0  26.5500        S   First
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 21         1       2    male  34.0      0      0  13.0000        S  Second
#
#       who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 1   woman       False    C    Cherbourg   yes  False          NaN
# 6     man        True    E  Southampton    no   True          NaN
# 11  woman       False    C  Southampton   yes   True          NaN
# 16  child       False  NaN   Queenstown    no  False          NaN
# 21    man        True    D  Southampton   yes   True          NaN

# %% [markdown]
# ###### 12. Write a Pandas program to filter those records where embarked matches with multiple values (C, Q) from the dataset.

# %%
#### code here
df['embarked'].isin(['C','Q'])
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Unnamed: 15
# 0      man        True  NaN  Southampton    no  False          NaN
# 1    woman       False    C    Cherbourg   yes  False          NaN
# 2    woman       False  NaN  Southampton   yes   True          NaN
# 3    woman       False    C  Southampton   yes  False          NaN
# 4      man        True  NaN  Southampton    no   True          NaN
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True          NaN
# 887  woman       False    B  Southampton   yes   True          NaN
# 888  woman       False  NaN  Southampton    no  False          NaN
# 889    man        True    C    Cherbourg   yes   True          NaN
# 890    man        True  NaN   Queenstown    no   True          NaN
#
# [889 rows x 16 columns]
